# %%
import datetime
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.finance import candlestick_ohlc
from matplotlib.axes import Axes
from matplotlib.dates import date2num

# %%
def convert_dates(date_list, interval):
    start_datetime = float(date_list[0][1:])
    start_datetime = datetime.datetime.fromtimestamp(start_datetime)
    add_interval = datetime.timedelta(seconds=interval)
    for i in range(len(date_list)):
        date_list[i] = start_datetime + add_interval*i
    return date_list

# %%
def grab_data(ticker, day_chart):
    ticker = ticker.upper()
    base_url = 'https://www.google.com/finance/getprices?q={}'.format(ticker)
    date_of_interest = datetime.datetime.timestamp(day_chart)
    interval = 60
    period = 1
    period_unit = 'd'
    params = '&ts={}&i={}&p={}{}&f=d,o,h,l,c,v'.format(date_of_interest,
                                                       interval,
                                                       period,
                                                       period_unit)
    url = base_url+params
    headers = 'date, open, high, low, close, volume'.split(', ')
    data = pd.read_csv(url, skiprows=7, names=headers)
    dates = convert_dates(data['date'].tolist(), 60)
    dates = pd.Series(dates)
    data['date'] = dates
    return data

# %%
def plot_data(data):
    # %matplotlib inline
    candlestick_ohlc(
                     plt.gca(),
                     list(zip(
                      date2num(data.date.dt.to_pydatetime().tolist()),
                      data.open.tolist(),
                      data.high.tolist(),
                      data.low.tolist(),
                      data.close.tolist(),
                      data.volume.tolist(),
                      )),
                     width=0.00068,
                     colorup='g',
                     colordown='r',
                     )
    plt.show()

# %%
ticker = 'clnt'
chart_day = datetime.datetime(2017,1,3,9,30)

# %%
data = grab_data(ticker, chart_day)
plot_data(data)
